# %% [markdown]
# # Creative MapLibreum Examples & Tutorials

# %% [markdown]
# MapLibreum ships with a curated set of base styles (such as `basic`, `streets`, and `satellite`) so you can start with a clean and familiar look straight away.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Quick Start: Hello MapLibreum
# Display a map centered on New York City and add a friendly greeting marker.

# %%
from maplibreum import Map

m = Map(center=[-74.0060, 40.7128], zoom=12)
m.add_marker(popup="Welcome to NYC!")
m
# Out:
# <iframe id="maplibreum_af30abd2fbcb45329e2bf31e2df30903_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_af30abd2fbcb45329e2bf31e2df30903 {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_af30abd2fbcb45329e2bf31e2df30903 { width: 100%; height: 500px; }
#
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_af30abd2fbcb45329e2bf31e2df30903&quot;&gt;
#
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_af30abd2fbcb45329e2bf31e2df30903&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_af30abd2fbcb45329e2bf31e2df30903&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [-74.006, 40.7128], &quot;zoom&quot;: 12});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#     map.addSource(&quot;source_0075f88b9b404b2ea1c98e7a60d8d56a&quot;, {&quot;type&quot;: &quot;geojson&quot;, &quot;data&quot;: {&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-74.006, 40.7128]}, &quot;properties&quot;: {}}]}});
#
#
#
#
#
#     // Add layers
#
#     map.addLayer({&quot;id&quot;: &quot;marker_264bada425554ff79a98a6ba1799e5a8&quot;, &quot;type&quot;: &quot;circle&quot;, &quot;source&quot;: &quot;source_0075f88b9b404b2ea1c98e7a60d8d56a&quot;, &quot;paint&quot;: {&quot;circle-radius&quot;: 8, &quot;circle-color&quot;: &quot;#007cbf&quot;, &quot;circle-stroke-width&quot;: 1, &quot;circle-stroke-color&quot;: &quot;#fff&quot;}});
#
#
#     // Popups
#
#     var popup_1 = new maplibregl.Popup({});
#
#     popup_1.setHTML(`Welcome to NYC!`);
#
#
#
#     map.on(&#x27;click&#x27;, &#x27;marker_264bada425554ff79a98a6ba1799e5a8&#x27;, function(e) {
#         popup_1
#             .setLngLat(e.lngLat)
#             .setHTML(`Welcome to NYC!`)
#             .addTo(map);
#     });
#
#
#
#     // Tooltips
#
#
#     // Tile Layers
#     var tileLayers = [
#
#     ];
#
#     // Overlay Layers
#     var overlayLayers = [
#
#     ];
#
#
#
#
#
#     // Markers
#
#
#
#
#
#
#     // Queued camera actions
#
# });
#
#
#
#
#
#
#
#             } catch (error) {
#                 console.error(&#x27;Error initializing map:&#x27;, error);
#                 showMapError(&#x27;Error initializing the map: &#x27; + error.message);
#             }
#         }
#     &lt;/script&gt;
#
#     &lt;!-- Load additional libraries with fallbacks --&gt;
#
#
#
#
#
# &lt;/body&gt;
#
# &lt;/html&gt;" style="width: 100%; height: 500px; border: none;" loading="lazy"></iframe>

# %% [markdown]
# `add_marker` lets you customize coordinates, popup text, marker color, clustering, icons, tooltips, and draggability.

# %% [markdown]
# ## 2. Custom Icons & Tooltips
# Use a BeautifyIcon for eye-catching markers that provide extra context to your users.

# %%
from maplibreum import Map
from maplibreum.markers import BeautifyIcon

m = Map(center=[2.3522, 48.8566], zoom=13)
icon = BeautifyIcon(icon="fa fa-coffee", background_color="#d35400")
m.add_marker(coordinates=[2.3522, 48.8566],
             icon=icon,
             tooltip="Coffee shop")
m
# Out:
# <iframe id="maplibreum_54ecb18017624d32aef80e9a795272aa_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_54ecb18017624d32aef80e9a795272aa {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_54ecb18017624d32aef80e9a795272aa { width: 100%; height: 500px; }
# .beautify-marker {display:flex;align-items:center;justify-content:center;width:26px;height:26px;line-height:26px;}.beautify-marker-marker {border-radius:13px 13px 13px 0;transform:rotate(-45deg);background-color:#d35400;border:2px solid #b8b8b8;}.beautify-marker-marker i {transform:rotate(45deg);color:white;}
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_54ecb18017624d32aef80e9a795272aa&quot;&gt;
#
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_54ecb18017624d32aef80e9a795272aa&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_54ecb18017624d32aef80e9a795272aa&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [2.3522, 48.8566], &quot;zoom&quot;: 13});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#
#
#
#
#     // Add layers
#
#
#     // Popups
#
#
#     // Tooltips
#
#
#     // Tile Layers
#     var tileLayers = [
#
#     ];
#
#     // Overlay Layers
#     var overlayLayers = [
#
#     ];
#
#
#
#
#
#     // Markers
#
#
#     var el_marker_094c17d4305547699402b05405ba4c9f = document.createElement(&#x27;div&#x27;);
#     el_marker_094c17d4305547699402b05405ba4c9f.className = &quot;beautify-marker beautify-marker-marker&quot;;
#     el_marker_094c17d4305547699402b05405ba4c9f.innerHTML = `&lt;i class=&#x27;fa fa-coffee&#x27;&gt;&lt;/i&gt;`;
#     var marker_marker_094c17d4305547699402b05405ba4c9f = new maplibregl.Marker({ element: el_marker_094c17d4305547699402b05405ba4c9f })
#         .setLngLat([2.3522, 48.8566])
#         .addTo(map);
#
#
#
#     var tooltip_marker_094c17d4305547699402b05405ba4c9f = new maplibregl.Popup({closeButton: false});
#     marker_marker_094c17d4305547699402b05405ba4c9f.getElement().addEventListener(&#x27;mouseenter&#x27;, function() {
#         tooltip_marker_094c17d4305547699402b05405ba4c9f
#             .setLngLat(marker_marker_094c17d4305547699402b05405ba4c9f.getLngLat())
#             .setHTML(`Coffee shop`)
#             .addTo(map);
#     });
#     marker_marker_094c17d4305547699402b05405ba4c9f.getElement().addEventListener(&#x27;mouseleave&#x27;, function() {
#         tooltip_marker_094c17d4305547699402b05405ba4c9f.remove();
#     });
#
#
#
#
#
#
#
#
#     // Queued camera actions
#
# });
#
#
#
#
#
#
#
#             } catch (error) {
#                 console.error(&#x27;Error initializing map:&#x27;, error);
#                 showMapError(&#x27;Error initializing the map: &#x27; + error.message);
#             }
#         }
#     &lt;/script&gt;

# %% [markdown]
# `BeautifyIcon` accepts icon classes, colors, and shapes, making markers visually rich.

# %% [markdown]
# ## 3. Visualizing Density with Heatmaps
# Convert point data (for example, earthquakes) into a density heatmap for quick pattern recognition.

# %%
from maplibreum import Map

geojson = {"type": "FeatureCollection", "features": []}  # fill with point features
source = {"type": "geojson", "data": geojson}

m = Map(center=[-122.4194, 37.7749], zoom=10)
m.add_heatmap_layer("quakes", source)
m
# Out:
# <iframe id="maplibreum_9d55800e00684d0f82f7cafda39b4dc6_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_9d55800e00684d0f82f7cafda39b4dc6 {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_9d55800e00684d0f82f7cafda39b4dc6 { width: 100%; height: 500px; }
#
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_9d55800e00684d0f82f7cafda39b4dc6&quot;&gt;
#
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_9d55800e00684d0f82f7cafda39b4dc6&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_9d55800e00684d0f82f7cafda39b4dc6&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [-122.4194, 37.7749], &quot;zoom&quot;: 10});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#     map.addSource(&quot;source_e5483537490f49018cedac29b9e81e18&quot;, {&quot;type&quot;: &quot;geojson&quot;, &quot;data&quot;: {&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: []}});
#
#
#
#
#
#     // Add layers
#
#     map.addLayer({&quot;id&quot;: &quot;quakes&quot;, &quot;type&quot;: &quot;heatmap&quot;, &quot;paint&quot;: {&quot;heatmap-radius&quot;: 20, &quot;heatmap-intensity&quot;: 1, &quot;heatmap-opacity&quot;: 1, &quot;heatmap-color&quot;: [&quot;interpolate&quot;, [&quot;linear&quot;], [&quot;heatmap-density&quot;], 0, &quot;rgba(0,0,255,0)&quot;, 0.2, &quot;blue&quot;, 0.4, &quot;cyan&quot;, 0.6, &quot;lime&quot;, 0.8, &quot;yellow&quot;, 1, &quot;red&quot;]}, &quot;source&quot;: &quot;source_e5483537490f49018cedac29b9e81e18&quot;});
#
#
#     // Popups
#
#
#     // Tooltips
#
#
#     // Tile Layers
#     var tileLayers = [
#
#     ];
#
#     // Overlay Layers
#     var overlayLayers = [
#
#     ];
#
#
#
#
#
#     // Markers
#
#
#
#
#
#
#     // Queued camera actions
#
# });
#
#
#
#
#
#
#
#             } catch (error) {
#                 console.error(&#x27;Error initializing map:&#x27;, error);
#                 showMapError(&#x27;Error initializing the map: &#x27; + error.message);
#             }
#         }
#     &lt;/script&gt;
#
#     &lt;!-- Load additional libraries with fallbacks --&gt;
#
#
#
#
#
# &lt;/body&gt;
#
# &lt;/html&gt;" style="width: 100%; height: 500px; border: none;" loading="lazy"></iframe>

# %% [markdown]
# Heatmaps use sensible defaults for radius, intensity, opacity, and color gradient. Override them with the `paint` argument for more control.

# %% [markdown]
# ## 4. Choropleth Map
# Shade regions based on attribute values such as population or median income.

# %%
from maplibreum import Map, Choropleth

# Example GeoJSON with polygon features (simplified for demo)
geojson_polygons = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"id": "area1", "name": "Downtown"},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[[-74.01, 40.71], [-74.00, 40.71], [-74.00, 40.72], [-74.01, 40.72], [-74.01, 40.71]]]
            }
        },
        {
            "type": "Feature",
            "properties": {"id": "area2", "name": "Midtown"},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[[-74.01, 40.72], [-74.00, 40.72], [-74.00, 40.73], [-74.01, 40.73], [-74.01, 40.72]]]
            }
        }
    ]
}

# Population data mapping feature IDs to counts
pop_data = {"area1": 25000, "area2": 45000}

m = Map(center=[-74.005, 40.72], zoom=13)
Choropleth(geojson_polygons, pop_data, legend_title="Population").add_to(m)
m
# Out:
# <iframe id="maplibreum_303661e665cc43a0b5706ecc08d1d613_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_303661e665cc43a0b5706ecc08d1d613 {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_303661e665cc43a0b5706ecc08d1d613 { width: 100%; height: 500px; }
#
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_303661e665cc43a0b5706ecc08d1d613&quot;&gt;
#
#
#         &lt;div class=&quot;maplibreum-legend&quot;&gt;&lt;div&gt;&lt;strong&gt;Population&lt;/strong&gt;&lt;br&gt;&lt;div&gt;&lt;i style=&#x27;background:#ffffcc&#x27;&gt;&lt;/i&gt;25000.00 – 29000.00&lt;/div&gt;&lt;div&gt;&lt;i style=&#x27;background:#c2e699&#x27;&gt;&lt;/i&gt;29000.00 – 33000.00&lt;/div&gt;&lt;div&gt;&lt;i style=&#x27;background:#78c679&#x27;&gt;&lt;/i&gt;33000.00 – 37000.00&lt;/div&gt;&lt;div&gt;&lt;i style=&#x27;background:#31a354&#x27;&gt;&lt;/i&gt;37000.00 – 41000.00&lt;/div&gt;&lt;div&gt;&lt;i style=&#x27;background:#006837&#x27;&gt;&lt;/i&gt;41000.00 – 45000.00&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_303661e665cc43a0b5706ecc08d1d613&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_303661e665cc43a0b5706ecc08d1d613&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [-74.005, 40.72], &quot;zoom&quot;: 13});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#     map.addSource(&quot;choropleth_541afbea4a454fc2bf271daed8d56e41_source&quot;, {&quot;type&quot;: &quot;geojson&quot;, &quot;data&quot;: {&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;id&quot;: &quot;area1&quot;, &quot;name&quot;: &quot;Downtown&quot;, &quot;value&quot;: 25000, &quot;fillColor&quot;: &quot;#ffffcc&quot;}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Polygon&quot;, &quot;coordinates&quot;: [[[-74.01, 40.71], [-74.0, 40.71], [-74.0, 40.72], [-74.01, 40.72], [-74.01, 40.71]]]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;id&quot;: &quot;area2&quot;, &quot;name&quot;: &quot;Midtown&quot;, &quot;value&quot;: 45000, &quot;fillColor&quot;: &quot;#006837&quot;}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Polygon&quot;, &quot;coordinates&quot;: [[[-74.01, 40.72], [-74.0, 40.72], [-74.0, 40.73], [-74.01, 40.73], [-74.01, 40.72]]]}}]}});
#
#
#
#
#
#     // Add layers
#
#     map.addLayer({&quot;id&quot;: &quot;choropleth_340c734bebb548289d7c994a7de15b7d&quot;, &quot;type&quot;: &quot;fill&quot;, &quot;source&quot;: &quot;choropleth_541afbea4a454fc2bf271daed8d56e41_source&quot;, &quot;paint&quot;: {&quot;fill-color&quot;: [&quot;get&quot;, &quot;fillColor&quot;, [&quot;properties&quot;]], &quot;fill-opacity&quot;:

# %% [markdown]
# The `Choropleth` class computes data bins, colors each feature, and adds a legend automatically.

# %% [markdown]
# ## 5. Marker Clustering
# Group many markers together for a cleaner view while still conveying density.

# %%
from maplibreum import Map
import random

m = Map(center=[0, 0], zoom=2)
points = {
    "type": "FeatureCollection",
    "features": [
        {"type": "Feature",
         "geometry": {"type": "Point",
                       "coordinates": [random.uniform(-180, 180),
                                       random.uniform(-85, 85)]}}
        for _ in range(500)
    ]
}
m.add_clustered_geojson(points)
m
# Out:
# <iframe id="maplibreum_670a881cd3414486baae6fd8e349c09c_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_670a881cd3414486baae6fd8e349c09c {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_670a881cd3414486baae6fd8e349c09c { width: 100%; height: 500px; }
#
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_670a881cd3414486baae6fd8e349c09c&quot;&gt;
#
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_670a881cd3414486baae6fd8e349c09c&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_670a881cd3414486baae6fd8e349c09c&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [0, 0], &quot;zoom&quot;: 2});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#     map.addSource(&quot;clustered_geojson_93967a507f7b4457bffe69d9ece1ffec_source&quot;, {&quot;type&quot;: &quot;geojson&quot;, &quot;data&quot;: {&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-63.474527499127944, -18.55659590364634]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-99.498758578502, 16.816821436836932]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [119.03865793945312, -11.76607361483272]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [12.554529894543862, -41.613490812467276]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-158.21941231231418, 47.56658900955466]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [88.93983362365316, 36.87411963463042]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [141.93104891006936, 7.199145610220057]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-116.17582261060426, 51.400734498760755]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-52.8532804126402, -39.616573431405115]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [42.41156658802166, 73.70917752622856]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;

# %% [markdown]
# `add_clustered_geojson` sets up a clustered GeoJSON source and layers, letting MapLibre handle cluster rendering and counts.

# %% [markdown]
# ## 6. Time-Lapse Playback
# Animate timestamped features—ideal for tracking movement or events over time.

# %%
from maplibreum import Map
from maplibreum.timedimension import TimeDimension

data = {
    "type": "FeatureCollection",
    "features": [
        {"type": "Feature",
         "geometry": {"type": "Point", "coordinates": [-0.1, 51.5]},
         "properties": {"time": "2024-01-01T00:00:00Z"}},
        # add more features with increasing timestamps
    ],
}

m = Map()
TimeDimension(data, options={"interval": 1000}).add_to(m)
m
# Out:
# <iframe id="maplibreum_3a12a7bd67ee416db033aea93db77d23_iframe" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot; /&gt;
#     &lt;title&gt;MapLibreum Map&lt;/title&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;initial-scale=1,maximum-scale=1,user-scalable=no&quot; /&gt;
#     &lt;link href=&quot;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;this.onerror=null;this.href=&#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.css&#x27;;&quot; /&gt;
#
#
#
#
#     &lt;link href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.0/dist/leaflet.timedimension.control.min.css&quot; rel=&quot;stylesheet&quot; onerror=&quot;console.warn(&#x27;Failed to load time dimension CSS&#x27;)&quot; /&gt;
#
#     &lt;style&gt;
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #maplibreum_3a12a7bd67ee416db033aea93db77d23 {
#             width: 100%;
#             height: 500px;
#             position: relative;
#         }
#
#         .maplibreum-legend {
#             position: absolute;
#             bottom: 10px;
#             left: 10px;
#             background: rgba(255, 255, 255, 0.8);
#             padding: 6px;
#             font-size: 12px;
#             border-radius: 4px;
#         }
#
#         .maplibreum-legend div {
#             display: flex;
#             align-items: center;
#             margin-bottom: 4px;
#         }
#
#         .maplibreum-legend span {
#             display: inline-block;
#             width: 12px;
#             height: 12px;
#             margin-right: 4px;
#
#         }
#
#         #maplibreum_3a12a7bd67ee416db033aea93db77d23 { width: 100%; height: 500px; }
#
#
#
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;maplibreum_3a12a7bd67ee416db033aea93db77d23&quot;&gt;
#
#
#     &lt;/div&gt;
#     &lt;!-- MapLibre GL JS with CDN fallbacks --&gt;
#     &lt;script&gt;
#         // Function to load MapLibre GL JS with fallbacks
#         function loadMapLibreGL() {
#             return new Promise((resolve, reject) =&gt; {
#                 // Try loading from unpkg.com first
#                 const script1 = document.createElement(&#x27;script&#x27;);
#                 script1.src = &#x27;https://unpkg.com/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                 script1.onload = () =&gt; resolve();
#                 script1.onerror = () =&gt; {
#                     // Fallback to jsDelivr
#                     const script2 = document.createElement(&#x27;script&#x27;);
#                     script2.src = &#x27;https://cdn.jsdelivr.net/npm/maplibre-gl@3.4.0/dist/maplibre-gl.js&#x27;;
#                     script2.onload = () =&gt; resolve();
#                     script2.onerror = () =&gt; {
#                         // Last fallback to cdnjs
#                         const script3 = document.createElement(&#x27;script&#x27;);
#                         script3.src = &#x27;https://cdnjs.cloudflare.com/ajax/libs/maplibre-gl/3.4.0/maplibre-gl.min.js&#x27;;
#                         script3.onload = () =&gt; resolve();
#                         script3.onerror = () =&gt; reject(new Error(&#x27;Failed to load MapLibre GL JS from all CDNs&#x27;));
#                         document.head.appendChild(script3);
#                     };
#                     document.head.appendChild(script2);
#                 };
#                 document.head.appendChild(script1);
#             });
#         }
#
#         // Function to show error message when MapLibre fails to load
#         function showMapError(message) {
#             const mapDiv = document.getElementById(&#x27;maplibreum_3a12a7bd67ee416db033aea93db77d23&#x27;);
#             if (mapDiv) {
#                 mapDiv.innerHTML = `
#                     &lt;div style=&quot;
#                         display: flex;
#                         align-items: center;
#                         justify-content: center;
#                         height: 100%;
#                         background-color: #f8f9fa;
#                         border: 2px dashed #dee2e6;
#                         border-radius: 8px;
#                         text-align: center;
#                         padding: 20px;
#                         font-family: -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, &#x27;Roboto&#x27;, sans-serif;
#                     &quot;&gt;
#                         &lt;div&gt;
#                             &lt;div style=&quot;font-size: 48px; color: #6c757d; margin-bottom: 16px;&quot;&gt;🗺️&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 18px; color: #495057; margin-bottom: 8px;&quot;&gt;Map Loading Error&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 14px; color: #6c757d; margin-bottom: 16px;&quot;&gt;${message}&lt;/div&gt;
#                             &lt;div style=&quot;font-size: 12px; color: #6c757d;&quot;&gt;
#                                 This may be due to network restrictions or CDN availability issues.
#                                 &lt;br&gt;Try refreshing the page or check your internet connection.
#                             &lt;/div&gt;
#                         &lt;/div&gt;
#                     &lt;/div&gt;
#                 `;
#             }
#         }
#
#         // Load MapLibre and initialize map
#         loadMapLibreGL().then(() =&gt; {
#             // MapLibre loaded successfully, check if it&#x27;s available
#             if (typeof maplibregl === &#x27;undefined&#x27;) {
#                 throw new Error(&#x27;MapLibre GL JS loaded but not available&#x27;);
#             }
#             initializeMap();
#         }).catch(error =&gt; {
#             console.error(&#x27;Failed to load MapLibre GL JS:&#x27;, error);
#             showMapError(&#x27;Failed to load MapLibre GL JavaScript library&#x27;);
#         });
#
#         function initializeMap() {
#             try {
#         // Initialize map
#         var map = new maplibregl.Map({&quot;container&quot;: &quot;maplibreum_3a12a7bd67ee416db033aea93db77d23&quot;, &quot;style&quot;: &quot;https://demotiles.maplibre.org/style.json&quot;, &quot;center&quot;: [0, 0], &quot;zoom&quot;: 2});
#
#
# // Add controls
#
#
#
#
#
#
# map.on(&#x27;load&#x27;, function() {
#
#     // Add sources
#
#
#
#
#
#     // Add layers
#
#
#     // Popups
#
#
#     // Tooltips
#
#
#     // Tile Layers
#     var tileLayers = [
#
#     ];
#
#     // Overlay Layers
#     var overlayLayers = [
#
#     ];
#
#
#
#
#
#     // Markers
#
#
#
#
#
#     var tdData = {&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-0.1, 51.5]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2024-01-01T00:00:00Z&quot;}}]};
#     map.addSource(&#x27;timedimension&#x27;, {type: &#x27;geojson&#x27;, data: tdData});
#     map.addLayer({
#         id: &#x27;timedimension&#x27;,
#         type: &#x27;circle&#x27;,
#         source: &#x27;timedimension&#x27;,
#         paint: { &#x27;circle-radius&#x27;: 5, &#x27;circle-color&#x27;: &#x27;#ff0000&#x27; }
#     });
#     var tdTimes = tdData.features.map(function(f){ return f.properties.time; }).sort();
#     var tdIndex = 0;
#     function tdStep(){
#         var t = tdTimes[tdIndex];
#         map.setFilter(&#x27;timedimension&#x27;, [&#x27;==&#x27;, [&#x27;get&#x27;,&#x27;time&#x27;], t]);
#         tdIndex = (tdIndex + 1) % tdTimes.length;
#     }
#     tdStep();
#     setInterval(tdStep, 1000);
#
#
#     // Queued camera actions
#
# });
#
#
#
#
#
#
#
#             } catch (error) {
#                 console.error(&#x27;Error initializing map:&#x27;, error);
#                 showMapError(&#x27;Error initializing the map: &#x27; + error.message);
#             }
#         }
#     &lt;/script&gt;
#
#     &lt;!-- Load additional libraries with fallbacks --&gt;
#
#
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.0/dist/leaflet.timedimension.min.js&quot; onerror=&quot;console.wa

# %% [markdown]
# `TimeDimension` wraps timestamped GeoJSON and exposes playback options such as interval speed.

# %% [markdown]
# ---
#
# ### Notes
# - Replace API keys or data sources (map tiles, GeoJSON) with your own where necessary.
# - Jupyter Notebook is recommended for interactive display (`pip install jupyter`).
#
# ### Testing
# No automated tests are run inside this notebook; code cells illustrate the API usage.
